# %% [markdown]
# Practice program of type casting

# %% [raw]
# convert a float into intger

# %%
float=75.7
integer=int(float)
print(f"float to int:(integer),type:{type(integer)}")
# Out:
# float to int:(integer),type:<class 'int'>

# %%
float=90.8
integer=int(float)
print(f"(integer),type:{type(integer)}")
# Out:
# (integer),type:<class 'int'>

# %%
float=89
string=int(float)
print(string)
# Out:
# 89

# %%
string=45.7
float=int(string)
print(float)
# Out:
# 45

# %%
integer=78
float=int(integer)
print(float)
# Out:
# 78

# %% [markdown]
# Check even and odd number

# %%
num=int(input("enter any number"))
if num% 2 == 0:
    print(num,"is an even number")
else:
    print(num,"is odd number")
# Out:
# enter any number 89
# 89 is odd number

# %%
p=int(input("Enter any number"))
q=int(input("Enter any number"))
if num% 2 == 0:
      print("Even number")
else:
     print("odd number")
# Out:
# Enter any number 45
# Enter any number 42
# odd number

# %%
num = int(input("Enter a non-negative integer: "))
factorial = 1
if num < 0:
    print("Factorial does not exist for negative numbers.")
elif num == 0:
    print("The factorial of 0 is 1.")
else:
    for i in range(1, num + 1):
        factorial *= i
    print("The factorial of", num, "is", factorial)
# Out:
# Enter a non-negative integer:  4
# The factorial of 4 is 24

# %%
p=int(input("Enter any number"))
factorial = 5
if p < 0:
    print("Factorial does not exits for negative numbers")
elif p == 0:
    print("The factorial of 0 is 1.")
else:
    for i in range(1,p+2):
        factorial *= i
    print("The factorial of", p, "is", factorial)
# Out:
# Enter any number 7
# The factorial of 7 is 201600

# %% [markdown]
# Program for the lagest number among 4 numbers.

# %%
n1=int(input("Enter any number"))
n2=int(input("Enter any number"))
n3=int(input("Enter any number"))
n4=int(input("Enter any number"))
if (n1>=n2) and (n1>=n3) and (n1>=n4):
    largest=n1
elif  (n2>=n1) and (n2>=n3) and (n2>=n4):
    largest=n2
elif  (n3>=n2) and (n3>=n2) and (n3>=n4):
    largest=n3
else:
    largest=n4
print("The largest number is",largest)
# Out:
# Enter any number 23
# Enter any number 45
# Enter any number 34
# Enter any number 56
# The largest number is 56

# %%
 #Python Program to find the L.C.M. of two input number
def compute_lcm(x, y):
   #choose the greater number
   if x > y:
       greater = x
   else:
       greater = y
   while(True):
       if((greater % x == 0) and (greater % y == 0)):
           lcm = greater
           break
       greater += 1
   return lcm
num1 = 5
num2 = 24
print("The L.C.M. is", compute_lcm(num1, num2))
# Out:
# The L.C.M. is 120
